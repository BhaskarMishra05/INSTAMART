# %% [markdown]
# # IMPORTS

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
import sys
import os
sys.path.append(os.path.abspath(".."))
from utilities import engin_creator

# %%
# !pip install mysql-connector-python

# %%
engin = engin_creator()

# %%
'''aisel_query = 'SELECT * FROM aisles'
df_aisel = pd.read_sql(aisel_query, engin)

department_query = 'SELECT * FROM departments'
df_department = pd.read_sql(department_query, engin)

order_product_train = 'SELECT * FROM order_products__train'
df_opt = pd.read_sql(order_product_train, engin)

order_query = 'SELECT * FROM orders'
df_order = pd.read_sql(order_query, engin)

products_query = 'SELECT * FROM products'
df_products = pd.read_sql(products_query, engin)'''

# %%
DF_AISEL = pd.read_csv('/home/korty/Code_House/VS_CODE/INSTAMART/Files/Database_Inhibitor/aisles.csv')
DF_ORDER = pd.read_csv('/home/korty/Code_House/VS_CODE/INSTAMART/Files/Database_Inhibitor/orders.csv')
DF_DEPARTMENT = pd.read_csv('/home/korty/Code_House/VS_CODE/INSTAMART/Files/Database_Inhibitor/departments.csv')
DF_PRODUCTS = pd.read_csv('/home/korty/Code_House/VS_CODE/INSTAMART/Files/Database_Inhibitor/products.csv')
DF_ORDER_PRODUCTS_PRIOR = pd.read_csv('/home/korty/Code_House/VS_CODE/INSTAMART/Files/Database_Inhibitor/order_products__prior.csv')

# %% [markdown]
# # DATA CLEANING

# %% [markdown]
# ### AISEL TABLE

# %%
DF_AISEL.head()
# Out:
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation
